# %% [markdown]
# # Analyze Benchmarking Results

# %%
from benchmarking.utils.visualize import create_row_count_v_time_line_plot, create_num_groups_v_time_line_plot, create_preprocess_v_load_time_chart
from benchmarking.utils.analyze import load_results_data

import warnings
warnings.filterwarnings(action="ignore", category=UserWarning)

# %%
data = load_results_data(package_version="v0.2.4")

# %%
data.head()
# Out:
#    row_count graph_structure  load_time  process_time load_strategy  \
# 0         10       bipartite   0.851936      0.000000        serial
# 1         10       bipartite   4.023329      1.585915      parallel
# 2         10       bipartite   5.895213      1.423282      parallel
# 3        100       bipartite   0.843146      0.000000        serial
# 4        100       bipartite   3.715283      1.392883      parallel
#
#    num_groups  total_time
# 0           1    0.851936
# 1           3    5.609245
# 2           5    7.318496
# 3           1    0.843146
# 4           3    5.108166

# %%
create_row_count_v_time_line_plot(data)
# Out:
# <Axes: title={'center': 'Serial vs. Parallel Ingest Using Spark'}, xlabel='Row Count', ylabel='Load Time (s)'>

# %%
create_num_groups_v_time_line_plot(data, "load_time")
# Out:
# array([<Axes: title={'center': '10 Samples'}, xlabel='Graph Structure', ylabel='Load Time (s)'>,
#        <Axes: title={'center': '100 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '1000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '10000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '100000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>],
#       dtype=object)

# %%
create_num_groups_v_time_line_plot(data, "process_time")
# Out:
# array([<Axes: title={'center': '10 Samples'}, xlabel='Graph Structure', ylabel='Preprocess Time (s)'>,
#        <Axes: title={'center': '100 Samples'}, xlabel='Graph Structure', ylabel='process_time'>,
#        <Axes: title={'center': '1000 Samples'}, xlabel='Graph Structure', ylabel='process_time'>,
#        <Axes: title={'center': '10000 Samples'}, xlabel='Graph Structure', ylabel='process_time'>,
#        <Axes: title={'center': '100000 Samples'}, xlabel='Graph Structure', ylabel='process_time'>],
#       dtype=object)

# %%
create_num_groups_v_time_line_plot(data, "total_time")
# Out:
# array([<Axes: title={'center': '10 Samples'}, xlabel='Graph Structure', ylabel='Total Time (s)'>,
#        <Axes: title={'center': '100 Samples'}, xlabel='Graph Structure', ylabel='total_time'>,
#        <Axes: title={'center': '1000 Samples'}, xlabel='Graph Structure', ylabel='total_time'>,
#        <Axes: title={'center': '10000 Samples'}, xlabel='Graph Structure', ylabel='total_time'>,
#        <Axes: title={'center': '100000 Samples'}, xlabel='Graph Structure', ylabel='total_time'>],
#       dtype=object)

# %%
create_preprocess_v_load_time_chart(data)
# Out:
# <Axes: title={'center': 'Serial vs. Parallel Ingest Load & Preprocessing Times'}, xlabel='Load Time (s)', ylabel='Total Time (s)'>
