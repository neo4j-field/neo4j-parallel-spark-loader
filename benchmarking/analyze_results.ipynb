# %% [markdown]
# # Analyze Benchmarking Results

# %%
from benchmarking.utils.visualize import create_row_count_v_time_line_plot, create_num_groups_v_time_line_plot
from benchmarking.utils.analyze import load_results_data

# %%
data = load_results_data(package_version="v0.2.2")

# %%
data.head()
# Out:
#    row_count graph_structure  load_time  process_time load_strategy  \
# 0         10       bipartite   0.851936      0.000000        serial
# 1         10       bipartite   4.023329      1.585915      parallel
# 2         10       bipartite   5.895213      1.423282      parallel
# 3        100       bipartite   0.843146      0.000000        serial
# 4        100       bipartite   3.715283      1.392883      parallel
#
#    num_groups  total_time
# 0           1    0.851936
# 1           3    5.609245
# 2           5    7.318496
# 3           1    0.843146
# 4           3    5.108166

# %%
create_row_count_v_time_line_plot(data)
# Out:
# <Axes: title={'center': 'Serial vs. Parallel Ingest Using Spark'}, xlabel='Row Count', ylabel='Load Time (s)'>

# %%
create_num_groups_v_time_line_plot(data)
# Out:
# [([<matplotlib.patches.Rectangle object at 0x10efedbb0>, <matplotlib.patches.Rectangle object at 0x10f1617f0>], ['3', '5']), ([<matplotlib.patches.Rectangle object at 0x10f5142f0>, <matplotlib.patches.Rectangle object at 0x10f5aaff0>], ['3', '5']), ([<matplotlib.patches.Rectangle object at 0x10f5eaa20>, <matplotlib.patches.Rectangle object at 0x10f5ea5d0>], ['3', '5']), ([<matplotlib.patches.Rectangle object at 0x10f62b620>, <matplotlib.patches.Rectangle object at 0x10f62ad20>], ['3', '5']), ([<matplotlib.patches.Rectangle object at 0x10f66bbc0>, <matplotlib.patches.Rectangle object at 0x10f66aa20>], ['3', '5'])]
# [<matplotlib.patches.Rectangle object at 0x10efedbb0>, <matplotlib.patches.Rectangle object at 0x10f1617f0>, <matplotlib.patches.Rectangle object at 0x10f5142f0>, <matplotlib.patches.Rectangle object at 0x10f5aaff0>, <matplotlib.patches.Rectangle object at 0x10f5eaa20>, <matplotlib.patches.Rectangle object at 0x10f5ea5d0>, <matplotlib.patches.Rectangle object at 0x10f62b620>, <matplotlib.patches.Rectangle object at 0x10f62ad20>, <matplotlib.patches.Rectangle object at 0x10f66bbc0>, <matplotlib.patches.Rectangle object at 0x10f66aa20>]
# ['3', '5', '3', '5', '3', '5', '3', '5', '3', '5']
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# array([<Axes: title={'center': '10 Samples'}, xlabel='Load Time (s)', ylabel='load_time'>,
#        <Axes: title={'center': '100 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '1000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '10000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>,
#        <Axes: title={'center': '100000 Samples'}, xlabel='Graph Structure', ylabel='load_time'>],
#       dtype=object)

# %% [markdown]
# line chart with load time and total time comparison
