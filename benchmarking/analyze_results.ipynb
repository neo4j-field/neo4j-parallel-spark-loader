# %% [markdown]
# # Analyze Benchmarking Results

# %%
from benchmarking.utils.visualize import create_row_count_v_time_line_plot, create_num_groups_v_time_line_plot
from benchmarking.utils.analyze import load_results_data

# %%
data = load_results_data(package_version="v0.2.0")

# %%
data.head()
# Out:
#    row_count graph_structure  load_time load_strategy  num_groups
# 0         12       bipartite   0.635141        serial           1
# 1         12       bipartite   3.677257      parallel           2
# 2         12       bipartite   3.913686      parallel           3
# 3         81       bipartite   0.697911        serial           1
# 4         81       bipartite   3.203136      parallel           2

# %%
create_row_count_v_time_line_plot(data)
# Out:
# <Axes: title={'center': 'Serial vs. Parallel Ingest Using Spark'}, xlabel='Row Count', ylabel='Load Time (s)'>

# %%
create_num_groups_v_time_line_plot(data)
# Out:
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# /Users/alexandergilmore/Documents/projects/neo4j-parallel-spark-loader/benchmarking/utils/visualize.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["bip", "mon", "pdc"])
# ...
